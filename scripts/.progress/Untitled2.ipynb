# %%
import cv2
from matplotlib import pyplot as plt

with open('./temp', 'rb') as f:
    key = [int(b) for b in f.read()]
print(key[:10],'....')

im = cv2.imread('/home/jules/images/pictures/Phone Chloé/IMG_0417.PNG')
plt.imshow(im)
plt.figure(figsize=(13, 7))
plt.show()
# Out:
# [149, 3, 151, 4, 93, 156, 164, 39, 1, 8] ....
